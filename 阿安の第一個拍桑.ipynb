# %%
1+1
# Out:
# 2

# %%
#shift+enter=換行

# %%
# %matplotlib inline

import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
# %是魔術指令
# 每次打開都打這幾行（as是命名，以後就不用打這麼長）

# %%
plt.plot([3,-5,2,7,10,-9])

# %%
#他會填x座標，我們填的是y座標

# %%
y=[3,-2,5,7,-10]

# %%
#數據結構的串列（也就是有限的數列）

# %%
plt.plot(y)

# %%
#放函數是小括號()

# %%
x=[0,0.7,3,4.2,7]

# %%
y
# Out:
# [3, -2, 5, 7, -10]

# %%
#看內容就直接打完shift+enter

# %%
plt.plot(x,y)

# %%
plt.scatter(x,y)

# %%
#jupyter notebook 支援markdown語法，想要放大標題、插入圖⋯⋯，可以用來一邊寫筆記一邊打程式，也需要常常標示自己在寫什麼來確認比較多行的程式

# %% [markdown]
# # markdown用法
# ## 一個井字是大標題；兩個是第二大標題（以此類推）
# ## 把上面的code下拉變成markdown 就會變黑字
# ## shift+enter 就會執行
# ## 快捷鍵 control（進入指令狀態） --> M

# %% [markdown]
# # 我們要學習
# * Python
# * matplotlib
# * numpy

# %%
# 圖copy到一樣的資料夾裡（需要記得完整的檔名）
# 圖片格式？？？？？

# %%
![圖](IMG_0413)
# Out:
# /bin/sh: -c: line 0: syntax error near unexpected token `IMG_0413'
# /bin/sh: -c: line 0: `[圖](IMG_0413)'

# %%
# 數學式子前後加$，強調就按兩個$

# %%
假設我們有個函數  $ f(x)=x^3-2X^2+1 $
# Out:
#   File "<ipython-input-38-cf5e30bf5c5c>", line 1
#     假設我們有個函數  $ f(x)=x^3-2X^2+1 $
#               ^
# SyntaxError: invalid syntax

# %%
x = np.linspace(0,1,50)

# %%
#shift+tab 或tab兩次 會有解說
# 表示0~1；50個點

# %%
y = np.cos(x)

# %%
plt.plot(x,y)

# %%
plt.xkcd()

# %%
plt.plot(x,y)

# %%
# 漫畫風用一次就只能restart解決

# %%
x=[2008,2009,2010,2011,2012,2013,2014,2015,2016]
y=[60,142,385,550,665,760,1050,1240,1500]
plt.plot(x,y)

# %%
plt.xkcd()

# %%
x=[2008,2009,2010,2011,2012,2013,2014,2015,2016]
y=[60,142,385,550,665,760,1050,1240,1500]
plt.plot(x,y)
